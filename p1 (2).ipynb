# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\bmsce\anaconda3\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\bmsce\anaconda3\lib\site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\bmsce\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\bmsce\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\bmsce\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\bmsce\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv(r"C:\Users\BMSCE\Desktop\Dataset_Ques_1_4 (1).csv")
months=df["month_number"]
total_profit=df['total_profit']
bathing_soap_sales=df['bathingsoap']
facewash_sales=df['facewash']
plt.figure(figsize=(10,5))
plt.plot(months, total_profit, linestyle='dotted', color='green', marker='s', label= 'Total Profit')
for i, txt in enumerate(total_profit):
    plt.annotate(txt, (months[i], total_profit[i]), textcoords="offset points", xytext=(0,5), ha="center")
plt.xlabel('Month')
plt.ylabel('Total Profit')
plt.title('Total Profit per Month')
plt.xticks(rotation=45)  
plt.grid(True)         
plt.legend()
plt.show()

fig, axes=plt.subplots(2,1,figsize=(10,8),sharex=True)
for i, txt in enumerate(bathing_soap_sales): 
    axes[0].annotate(txt,(months[i], bathing_soap_sales[i]), textcoords="offset points", xytext=(0,5), ha="center")
axes[0].plot(months, bathing_soap_sales, marker='o', linestyle='-', color='red', label= 'bathing_soap_sales')
axes[0].set_title('Bathing Soap Sales per Month')
axes[0].set_ylabel('Sales')
axes[0].legend()
axes[0].grid(True)           


for i, txt in enumerate(facewash_sales): 
    axes[1].annotate(txt,(months[i], facewash_sales[i]), textcoords="offset points", xytext=(0,5), ha="center")
axes[1].plot(months, facewash_sales, marker='o', linestyle='-', color='blue', label= 'facewash_sales')
axes[1].set_title('Facewash Sales per Month')
axes[1].set_xlabel('Month')
axes[1].set_ylabel('Sales')
axes[1].legend()
axes[1].grid(True)

# %%
plt.figure(figsize=(10,5))
plt.plot(df["month_number"], df["total_profit"], linestyle= 'dashed', linewidth=2, color='green', marker='o')
plt.xlabel("months")
plt.ylabel("total_profit")
plt.title("Total Profit Per Month")
plt.legend(loc="lower right")
plt.xticks(rotation=45)
plt.grid(True)
plt.show()
plt.figure(figsize=(10,5))
plt.bar(df["month_number"], df["toothpaste"], color= "blue")
plt.xlabel("Month")
plt.ylabel("Toothpaste Sales")
plt.title("Toothpaste Per Month Profit")
plt.legend()
plt.xticks(rotation=45)
plt.yticks(rotation=45)
plt.grid(axis='y')
plt.show
# Out:
# C:\Users\BMSCE\AppData\Local\Temp\ipykernel_10852\3247923398.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(loc="lower right")
# C:\Users\BMSCE\AppData\Local\Temp\ipykernel_10852\3247923398.py:15: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import pandas as pd
import matplotlib.pyplot as plt
df= pd.read_csv(r"C:\Users\BMSCE\Desktop\Dataset_Ques_1_4 (1).csv")
product_cols =['facecream', 'facewash', 'toothpaste', 'bathingsoap', 'shampoo', 'moisturizer']
product_sales= df[product_cols].sum()
max_sale= product_sales.max()
explode_values= [0.1 if val == max_sale else 0 for val in product_sales]
sales_labels= [str(int(val)) for val in product_sales]
plt.figure(figsize=(10, 8))
plt.pie(
    product_sales,
    labels= sales_labels,
    explode= explode_values,
    startangle= 60,
    labeldistance= 0.7,
    shadow= True,
    textprops= {'weight':'bold'}
)
plt.legend(product_sales.index, title= "Products", loc="center left", bbox_to_anchor=(1, 0.5))
plt.title("Total Sales Data for each Product")
plt.axis('equal')
plt.tight_layout()
plt.show 


plt.figure(figsize=(8, 4))
plt.barh(['face cream', 'face wash'], [df['facecream'].sum(), df['facewash'].sum()], color=['skyblue', 'orange'])
plt.xlabel("Total Units Sold")
plt.title("Face Cream vs Face Wash Comparision")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
categories=['A','B','C','D','E']
means_men=[22,30,35,35,26]
means_women=[25,32,30,35,29]
bar_width=0.5
plt.bar(categories,means_men,width=bar_width,label='Men',color='skyblue')
plt.bar(categories,means_women,width=bar_width,bottom=means_men, label='Women',color='pink')
plt.xlabel('Categories')
plt.ylabel('Means')
plt.title("Scores by Group and Gender")
plt.xticks(categories)
plt.yticks(np.arange(0,81,10))
for i in range(len(categories)):
    plt.text(i,means_men[i]+means_women[i]/2,str(means_women[i]),ha='center',va='center',fontweight='bold')
    plt.text(i,means_men[i]/2,str(means_men[i]),ha='center',va='center',fontweight='bold')
plt.legend(loc='upper right')
plt.tight_layout
plt.savefig('stacked_bar_plot.jpeg')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
subjects= ['DSC', 'OOP', 'OPS', 'COA', 'MAT', 'Java']
pass_percentage= [40, 25.6, 8.8, 30, 7.7, 60.7]
explode= [0, 0, 0, 0, 0, 0.1]
plt.figure(figsize=(7,7))
plt.pie(pass_percentage, labels= subjects, autopct= '%1.1f%%', startangle= 100, explode= explode, shadow= True)
plt.title("Pass Percentage of Subjects")
df=pd.read_csv(r"C:\Users\BMSCE\Desktop\sub 1.csv")
subject_pass_percentage= df['pass_percentage']
min_pass_percentage= subject_pass_percentage.max()
subject= df['subjects']
explode_values= [0.1 if val == min_pass_percentage else 0 for val in subject_pass_percentage]
plt.figure(figsize=(10, 8))
plt.pie(
    subject_pass_percentage,
    labels=subject,
    explode= explode_values,
    startangle= 60,
    autopct= '%1.1f%%',
    shadow= True,
    textprops= {'weight':'bold'}
)
plt.show()


df= pd.read_csv(r"C:\Users\BMSCE\Desktop\Dataset_Ques_1_4 (1).csv")
print(df.columns)
profit_data= df['total_profit']
plt.figure(figsize=(8,6))
plt.hist(profit_data, bins=10, color='orange', edgecolor= 'blue', alpha= 0.7)
plt.xlabel("Profit Ranges")
plt.ylabel("Frequency")
plt.title("Histogram of Monthly Profits")
plt.show()
# Out:
# Index(['month_number', 'facecream', 'facewash', 'toothpaste', 'bathingsoap',
#        'shampoo', 'moisturizer', 'total_units', 'total_profit'],
#       dtype='object')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
data= pd.read_csv(r"C:\Users\BMSCE\Desktop\planets.csv")
plt.figure(figsize=(10, 6))
sns.scatterplot(
    data=data,
    x='year',
    y= 'distance',
    hue= 'mass', 
    style= 'mass', 
    size= 'mass',
    sizes=(20, 200),
    palette= 'viridis',
    alpha=0.7 
)
plt.title('Distance Covered Year-wise with Mass as Additional Features')
plt.xlabel('Year')
plt.ylabel('Distance')
plt.legend(bbox_to_anchor=(1.05, 1), loc='best')
plt.grid(True)

plt.show()

plt.figure(figsize=(10, 6))
sns.histplot(
data=data,
x='orbital_period',
bins=20,
kde=True,
color='skyblue',
)
plt.title('Distribution of Orbital Periods')
plt.xlabel('Orbital Period')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()
import numpy as np
data['mass_category'] = pd.qcut(data['mass'], q=5, labels=['Very Low', 'Low', 'Medium', 'High','Very High'])
plt.figure(figsize=(10, 6))
sns.scatterplot(
data=data,
x='year',
y='distance',
hue='mass_category', 
style='mass_category',
size='mass',
color='purple',
sizes=(20, 200),
palette='viridis',
alpha=0.2
)
plt.title('Distance Covered Year-wise with Mass Categories')
plt.xlabel('Year')
plt.ylabel('Distance')
plt.legend(title="Mass Category", bbox_to_anchor=(1.05, 1), loc='upper left') 
plt.grid(True)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = sns.load_dataset('planets')
print(df)
sns.set_palette("muted")  
plt.figure(figsize=(12, 6))
scatter = sns.scatterplot(
    data=df,
    x='year',
    y='distance',
    hue='method',
    size='mass',
    sizes=(20, 200),
    alpha=0.7
)
plt.show()
plt.title("Distance vs Year with Method and Mass")
plt.xlabel("Discovery Year")
plt.ylabel("Distance")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
bar = sns.barplot(data=method_distance, x='method', y='distance', palette='viridis')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
plt.tight_layout()
plt.show()

method_distance = df.groupby('method')['distance'].mean().reset_index()
plt.figure(figsize=(12, 6))
print(method_distance)
bar = sns.barplot(data=method_distance, x='method', y='distance', palette='viridis')
plt.title("Average Distance by Discovery Method")
plt.xlabel("Discovery Method")
plt.ylabel("Average Distance")
plt.xticks(rotation=45, ha='right')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
plt.tight_layout()
plt.show()
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]
# C:\Users\BMSCE\AppData\Local\Temp\ipykernel_4820\3411221274.py:23: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   bar = sns.barplot(data=method_distance, x='method', y='distance', palette='viridis')
# C:\Users\BMSCE\AppData\Local\Temp\ipykernel_4820\3411221274.py:24: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
#                           method     distance
# 0                     Astrometry    17.875000
# 1      Eclipse Timing Variations   315.360000
# 2                        Imaging    67.715937
# 3                   Microlensing  4144.000000
# 4  Orbital Brightness Modulation  1180.000000
# 5                  Pulsar Timing  1200.000000
# 6    Pulsation Timing Variations          NaN
# 7                Radial Velocity    51.600208
# 8                        Transit   599.298080
# 9      Transit Timing Variations  1104.333333
# C:\Users\BMSCE\AppData\Local\Temp\ipykernel_4820\3411221274.py:31: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   bar = sns.barplot(data=method_distance, x='method', y='distance', palette='viridis')
# C:\Users\BMSCE\AppData\Local\Temp\ipykernel_4820\3411221274.py:36: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)

# %%
import turtle
import time
t = turtle.Turtle()
t.color("light blue")
t.width(3)
t.speed(1)
t.begin_fill()
t.left(140)
for i in range(200):
    t.forward(1)
    t.right(1)
    time.sleep(0.005)
t.left(120)
for i in range(200):
    t.forward(1)
    t.right(1)
    time.sleep(0.005)
t.forward(112)
t.end_fill()
turtle.done()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=sns.load_dataset('titanic')
sns.displot(data=df,x='age',kde=False,bins=30,color='skyblue')
plt.title("Distribution of Age")
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()
sns.kdeplot(data=df,x='age',fill=True,color='purple')
plt.title("Distribution of Age")
plt.xlabel("Age")
plt.ylabel("Destiny")
plt.show()
avg_fare=df.groupby('pclass')['fare'].mean().reset_index()
sns.lineplot(data=avg_fare,x='pclass',y='fare',marker='o',color='g')
plt.title("Average Fare by Passenger Class")
plt.xlabel("Passenger Class")
plt.ylabel("Fares")
plt.show()
sns.set_palette("Set1")
sns.scatterplot(data=df,x='age',y='fare',hue='survived',style='sex')
plt.title("Scatter Plot of Age vs Fare by Survival and Gender")
plt.xlabel("Age")
plt.ylabel("Fare")
plt.legend(title='Survived',bbox_to_anchor=(1.05,1),loc='upper left')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=sns.load_dataset('titanic')
sns.set_palette("Set2")
fig,axes=plt.subplots(2,1,figsize=(10,10))
sns.scatterplot(data=df,x='age',y='fare',hue='survived',ax=axes[0])
axes[0].set_title('Scatter Plot - Age vs Fare')
sns.scatterplot(data=df,x='age',y='pclass',hue='sex',ax=axes[1])
axes[1].set_title('Scatter Plot - Age vs Pclass')
plt.tight_layout()
plt.show()
sns.violinplot(data=df,x='pclass',y='age',hue='sex',split=0)
plt.title("Violin Plot of Age by Passenger Class and Sex")
plt.xlabel("Passenger Class")
plt.ylabel("Age")
plt.show()
survival_data=df.groupby(['pclass','survived']).size().reset_index(name='count')
sns.lineplot(data=survival_data,x='pclass',y='count',hue='survived',marker='o')
plt.title("Passenger Survival Count by Class")
plt.xlabel("Passenger Class")
plt.ylabel("Number of passengers")
plt.show()
sns.stripplot(data=df,x='sex',y='age',jitter=True,hue='survived',palette='Set2')
plt.title("Strip Plot of Age vs Sex(No Jitter)")
plt.xlabel("Sex")
plt.ylabel("Age")
plt.legend(title='Survived',bbox_to_anchor=(1.05,1),loc='upper left')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_palette("Set3")
df = sns.load_dataset('titanic')
order = df.groupby('class')['survived'].mean().sort_values().index
sns.catplot(data=df, x='class', y='survived', kind='bar', order=order)
plt.title("Survival Rate by Class (Reordered)")
plt.xlabel("Passenger Class")
plt.ylabel("Survival Rate")
plt.show()
sns.violinplot(data=df, x='class', y='age', hue='sex', split=True)
plt.title("Violin Plot of Age by Class and Sex")
plt.xlabel("Passenger Class")
plt.ylabel("Age")
plt.show()
fig, axes = plt.subplots(1, 3, figsize=(18, 5))
sns.lineplot(data=df, x='class', y='age', estimator='mean', ax=axes[0])
axes[0].set_title("Avg Age by Class")
sns.lineplot(data=df, x='class', y='fare', estimator='mean', ax=axes[1])
axes[1].set_title("Avg Fare by Class")
survival_rate = df.groupby('class')['survived'].mean().reset_index()
sns.lineplot(data=survival_rate, x='class', y='survived', marker='o', ax=axes[2])
axes[2].set_title("Survival Rate by Class")
plt.tight_layout()
plt.show()
sns.set_palette("GnBu")
sns.scatterplot(data=df, x='age', y='fare', hue='sex', style='survived')
plt.title("Scatter Plot of Age vs Fare (Colored by Sex &amp; Style by Survival)")
plt.xlabel("Age")
plt.ylabel("Fare")
plt.legend(title='Sex / Survival', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\BMSCE\AppData\Local\Temp\ipykernel_5724\188519967.py:6: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   order = df.groupby('class')['survived'].mean().sort_values().index
# C:\Users\BMSCE\AppData\Local\Temp\ipykernel_5724\188519967.py:22: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   survival_rate = df.groupby('class')['survived'].mean().reset_index()
